# %%
import yaml
import pandas as pd
from math import ceil

from utils import get_inventory, get_character_needs, get_mule_counts

# %%
get_inventory(verbose=True)
# Out:
# Total Monies: 1014.53
# Saving inventory data with (119, 6) shape

# %%
get_character_needs('Zegna')
# Out:
# {}

# %%
get_character_needs('Melue')
# Out:
# {'Thistle Tea': -2}

# %%
get_mule_counts()
# Out:
#                                       category  count
# item
# Grave Moss                                 Buy     22
# Firefin Snapper                            Buy     20
# Blindweed                                  Buy     16
# Stranglekelp                               Buy     10
# Thorium Ore                                Buy     10
# Fadeleaf                                   Buy      5
# Dreamfoil                                  Buy      4
# Dream Dust                                 Buy      1
# Thorium Bar                        Commodities     11
# Elemental Sharpening Stone         Commodities      6
# Essence of Water                   Commodities      5
# Arcanite Bar                       Commodities      4
# Fire Oil                          Intermediate     12
# Stonescale Oil                    Intermediate      3
# Greater Arcane Protection Potion          Sell     89
# Elixir of Superior Defense                Sell     59
# ...
